# %% [markdown]
# # Subject: Classical Data Analysis
#
# ## Session 4 - Working with Geopandas and ArcGIS Online
#
# ### Exercise 1 -  Interception Operation for Land Use and Land Cover and Barcelona districts

# %% [markdown]
# Installing GeoPandas
#
# To install the released version, you can use pip:

# %% [markdown]
# http://geopandas.org/install.html

# %% [markdown]
# *pip install geopandas*

# %% [markdown]
# or you can install the conda package from the conda-forge channel:

# %% [markdown]
# *conda install -c conda-forge geopandas*

# %% [markdown]
# Dependencies

# %% [markdown]
# Installation via conda should also install all dependencies, but a complete list is as follows:
#
# - numpy
# - pandas (version 0.15.2 or later)
# - shapely
# - fiona
# - pyproj

# %%
import pandas as pd
import geopandas as gpd
# %matplotlib inline

# %%
from shapely.geometry import shape,Point,Polygon,mapping

# %% [markdown]
# ## 1. Load shapefiles

# %% [markdown]
# ### 1.1. Load the "Barcelona districts " shapefile

# %%
shp1 = "C:\BTS_Master\ClassicalDataAnalysis\Session_4/Barcelona_districts.shp"

# %%
df_bcn_dist = gpd.read_file(shp1)

# %%
df_bcn_dist.head()
# Out:
#    cartodb_id  dones  homes  \
# 0           1  21850  26553
# 1          11  20693  20213
# 2          22   2397   2269
# 3          34   4729   4170
# 4          37  16537  15306
#
#                                                web_4  \
# 0  http://www.bcn.cat/estadistica/catala/dades/in...
# 1  http://www.bcn.cat/estadistica/catala/dades/in...
# 2  http://www.bcn.cat/estadistica/catala/dades/in...
# 3  http://www.bcn.cat/estadistica/catala/dades/in...
# 4  http://www.bcn.cat/estadistica/catala/dades/in...
#
#                                                web_3  \
# 0  http://www.bcn.cat/estadistica/catala/dades/gu...
# 1  http://www.bcn.cat/estadistica/catala/dades/gu...
# 2  http://www.bcn.cat/estadistica/catala/dades/gu...
# 3  http://www.bcn.cat/estadistica/catala/dades/gu...
# 4  http://www.bcn.cat/estadistica/catala/dades/gu...
#
#                                                web_2  \
# 0  http://www.bcn.cat/estadistica/catala/dades/in...
# 1  http://www.bcn.cat/estadistica/catala/dades/in...
# 2  http://www.bcn.cat/estadistica/catala/dades/in...
# 3  http://www.bcn.cat/estadistica/catala/dades/in...
# 4  http://www.bcn.cat/estadistica/catala/dades/in...
#
#                                    web_1  \
# 0         http://www.bcn.cat/ciutatvella
# 1      http://www.bcn.cat/sants-montjuic
# 2  http://www.bcn.cat/sarria-santgervasi
# 3      http://www.bcn.cat/horta-guinardo
# 4      http://www.bcn.cat/horta-guinardo
#
#                                  n_barri c_barri              n_distri  \
# 0                               el Raval      01          Ciutat Vella
# 1                           el Poble Sec      11       Sants-MontjuÃ¯c
# 2  Vallvidrera, el Tibidabo i les Planes      22  SarriÃ -Sant Gervasi
# 3                              Can BarÃ³      34       Horta-GuinardÃ³
# 4                              el Carmel      37       Horta-GuinardÃ³
#
#   c_distri       coord_y        coord_x         perim          area  \
# 0       01  4.581363e+06  430732.006258   5557.372878  1.098393e+06
# 1       03  4.579869e+06  429693.647708   9956.448009  4.604541e+06
# 2       05  4.585950e+06  423973.042970  34375.351100  1.152241e+07
# 3       07  4.585564e+06  430095.903925   4346.842889  3.837347e+05
# 4       07  4.586124e+06  429562.860855   6200.748289  9.415838e+05
#
#                                             geometry
# 0  POLYGON ((2.171192824800411 41.38659469413268,...
# 1  POLYGON ((2.150965984865441 41.37641964877194,...
# 2  (POLYGON ((2.073267395167333 41.41382817352449...
# 3  POLYGON ((2.168444030656322 41.41657572184046,...
# 4  POLYGON ((2.159485805207417 41.42671610208185,...

# %%
df_bcn_dist.crs # check the Cordinate system (CRS)
# Out:
# {'init': 'epsg:4326'}

# %%
selected_cols_bcn_dist = ['n_barri', 'n_distri', 'geometry']

# %%
df_bcn_dist_2 = df_bcn_dist[selected_cols_bcn_dist]
df_bcn_dist_2.head()
# Out:
#                                  n_barri              n_distri  \
# 0                               el Raval          Ciutat Vella
# 1                           el Poble Sec       Sants-MontjuÃ¯c
# 2  Vallvidrera, el Tibidabo i les Planes  SarriÃ -Sant Gervasi
# 3                              Can BarÃ³       Horta-GuinardÃ³
# 4                              el Carmel       Horta-GuinardÃ³
#
#                                             geometry
# 0  POLYGON ((2.171192824800411 41.38659469413268,...
# 1  POLYGON ((2.150965984865441 41.37641964877194,...
# 2  (POLYGON ((2.073267395167333 41.41382817352449...
# 3  POLYGON ((2.168444030656322 41.41657572184046,...
# 4  POLYGON ((2.159485805207417 41.42671610208185,...

# %%
df_bcn_dist_2.plot(column='n_barri', cmap='Set1', figsize=(12, 12))

# %% [markdown]
# ### 1.2. Load the "Corine Land Cover of Barcelona" shapefile

# %%
shp2 = "C:\BTS_Master\ClassicalDataAnalysis\Session_4/CLC12_Barcelona.shp"

# %%
df_clc_dist = gpd.read_file(shp2)

# %%
df_clc_dist.head()
# Out:
#    OBJECTID CLC_CODE               Level1  \
# 0         1      112  Artificial surfaces
# 1         2      121  Artificial surfaces
# 2         3      121  Artificial surfaces
# 3         4      121  Artificial surfaces
# 4         5      122  Artificial surfaces
#
#                                        Level2  \
# 0                                Urban fabric
# 1  Industrial, commercial and transport units
# 2  Industrial, commercial and transport units
# 3  Industrial, commercial and transport units
# 4  Industrial, commercial and transport units
#
#                                        Level3        Area         Per3D  \
# 0                  Discontinuous urban fabric   65.677140   6524.660900
# 1              Industrial or commercial units  715.589775  21306.505708
# 2              Industrial or commercial units    0.309275    225.092200
# 3              Industrial or commercial units   65.505163   4865.110863
# 4  Road and rail networks and associated land   96.234388  10392.731116
#
#                                             geometry
# 0  POLYGON Z ((2.146360960511865 41.3554683458670...
# 1  (POLYGON Z ((2.142555145569233 41.347187685652...
# 2  POLYGON Z ((2.107920993569771 41.3799034660792...
# 3  POLYGON Z ((2.122246031185429 41.3867973490756...
# 4  POLYGON Z ((2.146733919043439 41.3457927478894...

# %%
df_clc_dist.crs # check the Cordinate system (CRS)
# Out:
# {'init': 'epsg:4326'}

# %%
df_bcn_dist.crs == df_clc_dist.crs # check if the the Cordinate systems (CRS) of both shapefiles are equal.
# Out:
# True

# %%
selected_cols_bcn_clc = ['CLC_CODE', 'Level1', 'Level2', 'Level3', 'Area', 'geometry']

# %%
df_clc_dist_2 = df_clc_dist[selected_cols_bcn_clc]
df_clc_dist_2.head()
# Out:
#   CLC_CODE               Level1                                      Level2  \
# 0      112  Artificial surfaces                                Urban fabric
# 1      121  Artificial surfaces  Industrial, commercial and transport units
# 2      121  Artificial surfaces  Industrial, commercial and transport units
# 3      121  Artificial surfaces  Industrial, commercial and transport units
# 4      122  Artificial surfaces  Industrial, commercial and transport units
#
#                                        Level3        Area  \
# 0                  Discontinuous urban fabric   65.677140
# 1              Industrial or commercial units  715.589775
# 2              Industrial or commercial units    0.309275
# 3              Industrial or commercial units   65.505163
# 4  Road and rail networks and associated land   96.234388
#
#                                             geometry
# 0  POLYGON Z ((2.146360960511865 41.3554683458670...
# 1  (POLYGON Z ((2.142555145569233 41.347187685652...
# 2  POLYGON Z ((2.107920993569771 41.3799034660792...
# 3  POLYGON Z ((2.122246031185429 41.3867973490756...
# 4  POLYGON Z ((2.146733919043439 41.3457927478894...

# %%
df_clc_dist_2.plot(column='Level3', cmap='Set2',  figsize=(12, 12))

# %% [markdown]
# ## 2. Intersection operation

# %% [markdown]
# These two GeoDataFrames have some overlapping areas:

# %% [markdown]
# When using how='intersection', it returns only those geometries that are contained by both GeoDataFrames:

# %%
res_intersection = gpd.overlay(df_bcn_dist_2, df_clc_dist_2, how='intersection')
res_intersection.head()
# Out:
#                       n_barri         n_distri CLC_CODE               Level1  \
# 0  la Marina del Prat Vermell  Sants-MontjuÃ¯c      523         Water bodies
# 1  la Marina del Prat Vermell  Sants-MontjuÃ¯c      121  Artificial surfaces
# 2  la Marina del Prat Vermell  Sants-MontjuÃ¯c      122  Artificial surfaces
# 3  la Marina del Prat Vermell  Sants-MontjuÃ¯c      122  Artificial surfaces
# 4  la Marina del Prat Vermell  Sants-MontjuÃ¯c      523         Water bodies
#
#                                        Level2  \
# 0                               Marine waters
# 1  Industrial, commercial and transport units
# 2  Industrial, commercial and transport units
# 3  Industrial, commercial and transport units
# 4                               Marine waters
#
#                                        Level3        Area  \
# 0                               Sea and ocean  180.427736
# 1              Industrial or commercial units  715.589775
# 2  Road and rail networks and associated land    0.008954
# 3  Road and rail networks and associated land   96.234388
# 4                               Sea and ocean  180.427736
#
#                                             geometry
# 0  POLYGON Z ((2.173700037131697 41.3180910246230...
# 1  POLYGON Z ((2.10988729347793 41.34013663320026...
# 2  POLYGON Z ((2.110103381929308 41.3401294884277...
# 3  POLYGON Z ((2.112987673447912 41.3412060750032...
# 4  POLYGON Z ((2.152245786396936 41.3224931266741...

# %%
ax = res_intersection.plot(cmap='Reds',  figsize=(12, 8))

df_bcn_dist_2.plot(ax=ax, facecolor='none', edgecolor='k');

df_clc_dist_2.plot(ax=ax, facecolor='none', edgecolor='k');

# %% [markdown]
# ## Task1: Calculate the frequency table of the "CLC_CODE" variable.

# %%
x=res_intersection

# %%
counts = x['CLC_CODE'].value_counts()
counts
# Out:
# 111    147
# 112    118
# 141     88
# 312     58
# 121     47
# 523     46
# 323     40
# 123     25
# 122     22
# 231     20
# 311     19
# 142     11
# 313      2
# Name: CLC_CODE, dtype: int64

# %% [markdown]
# ## 3. Export the result as shapefile

# %% [markdown]
# First confirm the CRS. If it is not available, we have to define it.

# %%
res_intersection.crs == df_clc_dist.crs
# Out:
# False

# %%
# proj WGS84

res_intersection.crs= "+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs"

# %% [markdown]
# To save the shapefile in the same folder where the notebook is hosted:

# %%
res_intersection.to_file('C:\BTS_Master\ClassicalDataAnalysis\Session_4/res_intersection.shp', driver='ESRI Shapefile')

# %% [markdown]
# Select and export the first 50 rows as a new shapefile:

# %%
selection = res_intersection[0:50]
# 36  POLYGON Z ((2.141767697307351 41.3629585405990...
# 37  POLYGON Z ((2.148089701203217 41.3611441798498...
# 38  POLYGON Z ((2.148089701203217 41.3611441798498...
# 39  POLYGON Z ((2.148038572732546 41.3611226270142...
# 40  POLYGON Z ((2.145928398308853 41.3602384594530...
# 41  POLYGON Z ((2.145859373634192 41.3601949011052...
# 42  POLYGON Z ((2.149026735211772 41.3633734223888...
# 43  POLYGON Z ((2.149213927006538 41.3632382472141...
# 44  POLYGON Z ((2.188381279155184 41.3628239175657...
# 45  POLYGON Z ((2.201937450930191 41.3853433646052...
# 46  POLYGON Z ((2.202261694678465 41.3855929840807...
# 47  POLYGON Z ((2.214217026235597 41.3999777141018...
# 48  POLYGON Z ((2.214385662694887 41.3998384719334...
# 49  POLYGON Z ((2.213804754683698 41.3994458061665...

# %% [markdown]
# Write those rows into a new Shapefile:

# %%
selection.to_file('res_intersection_selection.shp', driver='ESRI Shapefile')

# %% [markdown]
# ## Task2:  Open the Shapefile in your ArcGIS Online account, and see how the data looks like. Create a new webmap and share with the BTS Group.

# %% [markdown]
# ## Task3: Using the "Filter function" answer to the following questions:
# - How many features you have in "El Poblenou" with the dominant code "111 - Artificial surfaces"?
# - Which districts have the less dominant "313 - Forest and semi natural areas"?

# %%
print('How many features you have in "El Poblenou" with the dominant code "111 - Artificial surfaces"?')
print(len(res_intersection[(res_intersection['n_barri'] == "el Poblenou") & (res_intersection['CLC_CODE'] == '111')]))

res_intersection[(res_intersection['n_barri'] == "el Poblenou") & (res_intersection['CLC_CODE'] == '111')]
# Out:
# How many features you have in "El Poblenou" with the dominant code "111 - Artificial surfaces"?
# 5
#          n_barri     n_distri CLC_CODE               Level1        Level2  \
# 63   el Poblenou  Sant MartÃ­      111  Artificial surfaces  Urban fabric
# 108  el Poblenou  Sant MartÃ­      111  Artificial surfaces  Urban fabric
# 109  el Poblenou  Sant MartÃ­      111  Artificial surfaces  Urban fabric
# 114  el Poblenou  Sant MartÃ­      111  Artificial surfaces  Urban fabric
# 486  el Poblenou  Sant MartÃ­      111  Artificial surfaces  Urban fabric
#
#                       Level3         Area  \
# 63   Continuous urban fabric    98.414289
# 108  Continuous urban fabric  3363.416126
# 109  Continuous urban fabric  3363.416126
# 114  Continuous urban fabric  3363.416126
# 486  Continuous urban fabric    98.414289
#
#                                               geometry
# 63   POLYGON Z ((2.205414542057224 41.3966531692796...
# 108  POLYGON Z ((2.199537597453923 41.3958130300259...
# 109  POLYGON Z ((2.20030585650604 41.39523489967363...
# 114  POLYGON Z ((2.200956203619437 41.3947455004212...
# 486  POLYGON Z ((2.195125158219394 41.4059880540555...

# %%
res_intersection[res_intersection['CLC_CODE'] == "313"]
# Out:
#                                    n_barri              n_distri CLC_CODE  \
# 578  Vallvidrera, el Tibidabo i les Planes  SarriÃ -Sant Gervasi      313
# 579  Vallvidrera, el Tibidabo i les Planes  SarriÃ -Sant Gervasi      313
#
#                             Level1   Level2        Level3      Area  \
# 578  Forest and semi natural areas  Forests  Mixed forest  1.378489
# 579  Forest and semi natural areas  Forests  Mixed forest  1.378489
#
#                                               geometry
# 578  POLYGON Z ((2.075313402711505 41.4364824241768...
# 579  POLYGON Z ((2.076544857772881 41.4340516494700...
